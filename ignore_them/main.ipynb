# %% [markdown]
# # Facial recognition
# will create unique id for every face on will output all the photos the person is in

# %% [markdown]
# ### Imprting everything needed

# %%
import pandas as pd 
import numpy as np
import cv2 
import os
import chromadb
from insightface.app import FaceAnalysis

# %%
model = FaceAnalysis(name="buffalo_l", providers=['CUDAExecutionProvider'])
model.prepare(ctx_id=0, det_size=(640, 640))
# Out:
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /home/arc/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /home/arc/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /home/arc/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /home/arc/.insightface/models/buffalo_l/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}, 'CUDAExecutionProvider': {'sdpa_kernel': '0', 'use_tf32': '1', 'fuse_conv_bias': '0', 'prefer_nhwc': '0', 'tunable_op_max_tuning_duration_ms': '0', 'enable_skip_layer_norm_strict_mode': '0', 'tunable_op_tuning_enable': '0', 'tunable_op_enable': '0', 'use_ep_level_unified_stream': '0', 'device_id': '0', 'has_user_compute_stream': '0', 'gpu_external_empty_cache': '0', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'cudnn_conv1d_pad_to_nc1d': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_alloc': '0', 'gpu_external_free': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'do_copy_in_default_stream': '1', 'enable_cuda_graph': '0', 'user_compute_stream': '0', 'cudnn_conv_use_max_workspace': '1'}}
# find model: /home/arc/.insightface/models/buffalo_l/w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %%
chroma_client = chromadb.PersistentClient(path = "sdf")
collection = chroma_client.get_or_create_collection(name="face_embeddings",
                                                    metadata={"hnsw:space": "cosine"})

# %%
import uuid
import shutil

# %% [markdown]
# ### Creating a filter for bluriness

# %%
def quality(img,face,blur,conf,ratio):
    if face.det_score < conf:
        return False
    bbox = face.bbox.astype(int)
    x1, y1, x2, y2 = bbox
    y1,y2 = max(0,y1), min(img.shape[0],y2)
    x1,x2 = max(0,x1), min(img.shape[1],x2)
    face_crop = img[y1:y2, x1:x2]
    if face_crop.size == 0:
        return False
    
    img_area = img.shape[0] * img.shape[1]
    face_area = (x2 - x1) * (y2 - y1)
    ratios = face_area / img_area
    if ratios < ratio:
        return False
    
    gray = cv2.cvtColor(face_crop, cv2.COLOR_BGR2GRAY)
    laplacian_var = cv2.Laplacian(gray, cv2.CV_64F).var()
    if laplacian_var < blur:
        return False
    return True

# %% [markdown]
# ### directories and stuff

# %%
dump = "/mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb"
output = "/mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/facial_output"
os.makedirs(output, exist_ok=True)
skipp = os.path.join(output,"skipped")
os.makedirs(skipp,exist_ok=True)

# %% [markdown]
# Parameters(will make it ui centric later)

# %%
dis_thres = 0.6
blur = 80
conf = 0.6
ratio =0.04

# %% [markdown]
# Generating embedding

# %%
for filename in os.listdir(dump):
    folder_path = os.path.join(dump, filename)
    if not os.path.isdir(folder_path):
        continue
    for img_path in os.listdir(folder_path):
        filepath = os.path.join(folder_path,img_path)
        img = cv2.imread(filepath)
        faces = model.get(img)
        for face in faces:
            Blur = quality(img,face,blur,conf,ratio)
            if not Blur:
                print(f"skipped {filepath} due to blurr")
                shutil.copy(filepath,os.path.join(skipp,img_path))
                continue
            embedding = face.embedding.tolist()
            results = collection.query(query_embeddings=[embedding], n_results=1)
            per_id = None
            if results['distances'][0] and results['distances'][0][0] < dis_thres:
                per_id = results['metadatas'][0][0]['per_id']
            else:
                per_id = f"Person_{str(uuid.uuid4())[:8]}"
                face_vector_id = str(uuid.uuid4())
                
                collection.add(
                    ids=[face_vector_id], 
                    embeddings=[embedding], 
                    metadatas=[{"per_id": per_id, "original_folder": folder_path,"filename": filename}]
                    )
            print(f"Image: {filepath}, Assigned ID: {per_id}")
            perid_out_dir = os.path.join(output,per_id)
            os.makedirs(perid_out_dir,exist_ok=True)
            shutil.copy(filepath,os.path.join(perid_out_dir,img_path))
# Out:
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpecximagesamazoncomimagesIfmaBKWLACULSRjpg.jpg, Assigned ID: Person_4ac70b95
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpssmediacacheakpinimgcomxffabffabbbcfbceaedjpg.jpg, Assigned ID: Person_bae3a02d
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpimagegaladevcmseamadonnaprivatdetektivsquaretopsquarejpgv.jpg, Assigned ID: Person_2c215d4c
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpwwwblackdogfilmscomwordpresswpcontentuploadsmadonnacelebrationxjpg.jpg, Assigned ID: Person_4292c496
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpsuploadwikimediaorgwikipediacommonsthumbaaMadonnaatthepremiereofIAmBecauseWeArejpgpxMadonnaatthepremiereofIAmBecauseWeArejpg.jpg, Assigned ID: Person_c3dc8364
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpssmediacacheakpinimgcomxdcfdcfedfaedadjpg.jpg, Assigned ID: Person_5e4bf776
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpwwwbeastiemaniacomwhoismadonnamadonnajpg.jpg, Assigned ID: Person_3c16182b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpssmediacacheakpinimgcomxffeabacaaejpg.jpg, Assigned ID: Person_8aefd1d0
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpuploadwikimediaorgwikipediacommonsthumbaMadonnaRotterdamjpgpxMadonnaRotterdamjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpssmediacacheakpinimgcomxaaeaaeecccaedfebdbjpg.jpg, Assigned ID: Person_95922df8
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpassetsrollingstonecomassetsimagesalbumreviewaffaceabdcccaeedjpg.jpg, Assigned ID: Person_b8ff3742
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpiamediaimdbcomimagesMMVBMTANDQNTAxNDVeQTJeQWpwZBbWUMDIMjQOTYVUXCRALjpg.jpg, Assigned ID: Person_8841122f
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpresizeparismatchladmediafrrffffffcentermiddleimgvarnewsstorageimagesparismatchpeopleazmadonnafreFRMadonnajpg.jpg, Assigned ID: Person_8841122f
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpcdncdnjustjaredcomwpcontentuploadsheadlinesmadonnatalksparisattackstearsjpg.jpg, Assigned ID: Person_8841122f
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpcdncdnjustjaredcomwpcontentuploadsheadlinesmadonnatalksparisattackstearsjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpssmediacacheakpinimgcomxffecfafddjpg.jpg, Assigned ID: Person_a42f55fa
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpimgclosermagfrvarclosermagstorageimagesactupeoplebiodestarsmadonnamadonnafreFRmadonnaexactxljpg.jpg, Assigned ID: Person_c3dc8364
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpcdnfuncheapcomwpcontentuploadsVOGUEjpg.jpg, Assigned ID: Person_5e4bf776
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpmediavoguecomrwblondesdarkbrowsmadonnajpg.jpg, Assigned ID: Person_814fa25a
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpsuploadwikimediaorgwikipediacommonsMadonnathAnnualGoldenGlobesAwardscroppedjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpssmediacacheakpinimgcomxafafedebcbjpg.jpg, Assigned ID: Person_418a24b4
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpwwwetonlinecomphotomadonnabdayjpg.jpg, Assigned ID: Person_9912be81
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpssvagalumecommadonnaimagesmadonnajpg.jpg, Assigned ID: Person_2154bbfc
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpssvagalumecommadonnaimagesmadonnajpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpssmediacacheakpinimgcomxfeebfdccajpg.jpg, Assigned ID: Person_e9e265ba
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/madonna/httpassetsrollingstonecomassetsarticlemadonnadavidbowiechangedthecourseofmylifeforeversmallsquarexmadonnabowiejpg.jpg, Assigned ID: Person_2c215d4c
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpsrobertaccetturacomwpcontentuploadsjerryseinfeldheadshotjpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpafilesbiographycomimageuploadcfillcssrgbdprgfacehqwMTIwNjANjMMDINzIxNjcjpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpblognjcomentertainmentimpactcelebritiesmediumjerrybjpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpaurorasblogcomwpcontentuploadsjerryseinfeldpublicityshotjpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpwwwwatchidcomsitesdefaultfilesuploadsightingBreitlingwatchJerrySeinfeldjpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpwwwpsychiatrictimescomsitesdefaultfilesimagesmediaPTMofficSeinfeldjpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpikinjaimgcomgawkermediaimageuploadsWmIuhdsrcedidjpgjpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httppfodcompchannelslegacyprofilejerryseinfeldpodcastjpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpcdncdnjustjaredcomwpcontentuploadsheadlinesjerryseinfeldmakesbrianwilliamsjokejpg.jpg, Assigned ID: Person_dcf9c5dd
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpcdncdnjustjaredcomwpcontentuploadsheadlinesjerryseinfeldmakesbrianwilliamsjokejpg.jpg due to blurr
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpcdncdnjustjaredcomwpcontentuploadsheadlinesjerryseinfeldmakesbrianwilliamsjokejpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpmediapopsugarassetscomfilesusersxlargejpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpimagescontactmusiccomnewsimagesjerryseinfeldjpg.jpg, Assigned ID: Person_2a7bf353
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpwwweonlinecomresizewwweonlinecomeolimagesEntireSitersxjerryseinfeldjulialouisdreyfusjwjpg.jpg due to blurr
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpwwweonlinecomresizewwweonlinecomeolimagesEntireSitersxjerryseinfeldjulialouisdreyfusjwjpg.jpg due to blurr
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpwwweonlinecomresizewwweonlinecomeolimagesEntireSitersxjerryseinfeldjulialouisdreyfusjwjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpimgthedrumcomsfspublicnewstmpjerryseinfeldjpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpsticketmnettmenusdbimagesajpg.jpg, Assigned ID: Person_dcf9c5dd
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpimgtimeincnetpeopleinewsjerryseinfeldjpg.jpg, Assigned ID: Person_dcf9c5dd
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpgraphicsnytimescomimagessectionmoviesfilmographyWireImagejpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpimagesrottentomatoescomimagesspotlightsnewsjerryseinfeldjpg.jpg, Assigned ID: Person_2a7bf353
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpwwwslatecomcontentdamslateblogsbrowbeatseinfeldjpgCROParticlemediumjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpswwwticketscomuploadsartistsjerryseinfeldbilletsjpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpsuploadwikimediaorgwikipediacommonsthumbbJerrySeinfeldjpgpxJerrySeinfeldjpg.jpg, Assigned ID: Person_2a7bf353
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpsuploadwikimediaorgwikipediacommonsthumbbJerrySeinfeldjpgpxJerrySeinfeldjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpcdnssninsidercomwpcontentuploadsjerryseinfeldxjpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpstatictherichestimagescomcdncwpcontentuploadsJerrySeinfeldjpg.jpg, Assigned ID: Person_dcf9c5dd
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpwwwnndbcompeoplejerryseinfeldaujpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpwwwpictureszimbiocomgpJerrySeinfeldJessicaSeinfeldmarriedBczSipMdNMQljpg.jpg, Assigned ID: Person_2a7bf353
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpsmedialivenationcomartiststapjpg.jpg, Assigned ID: Person_dcf9c5dd
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/jerry_seinfeld/httpsuswestamazonawscomblogsprodmediausuploadsJerrySeinfeldkidsxjpg.jpg, Assigned ID: Person_dcf9c5dd
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpbpblogspotcomedLMjVpRGkSWexgsXjkNIAAAAAAAADWgFFtAUqBlhAsjpg.jpg, Assigned ID: Person_44012e07
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpcsvkmeuaeccjpg.jpg, Assigned ID: Person_2e876786
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpsuploadwikimediaorgwikipediacommonsthumbddBenAffleckbyGageSkidmorejpgpxBenAffleckbyGageSkidmorejpg.jpg, Assigned ID: Person_1bf8f5bd
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpwwwaceshowbizcomimagesphotobenaffleckjpg.jpg, Assigned ID: Person_44012e07
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpssmediacacheakpinimgcomxeeedcacddeccccacfjpg.jpg, Assigned ID: Person_839dbac0
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpssmediacacheakpinimgcomxeebdfdbaaajpg.jpg, Assigned ID: Person_c74c92eb
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httptrwebimgacstanetcxbdddmediasnmediajpg.jpg, Assigned ID: Person_839dbac0
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpwwwfilmscoopitcgibinattoriBENAFFLECKBENAFFLECKjpg.jpg, Assigned ID: Person_27ebe490
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpssmediacacheakpinimgcomxdbbdbbbececacdecdcdfjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpabsolumentgratuitfreefrimagesbenaffleckjpg.jpg, Assigned ID: Person_44012e07
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpssmediacacheakpinimgcomxedaedabcbefbcbabbjpg.jpg, Assigned ID: Person_839dbac0
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpcsvkmeuaafdfjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpcsvkmeuadecafjpg.jpg, Assigned ID: Person_44012e07
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpwwwallposterscomimagesPostersPFjpg.jpg, Assigned ID: Person_44012e07
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpwwwhillsindcomstorebenjpg.jpg, Assigned ID: Person_44012e07
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpimagesfandangocomrImageRendererredesignstaticimgnoxportraitjpgpcpcpcimagesmasterrepositoryperformerimagespjpg.jpg, Assigned ID: Person_44012e07
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpssmediacacheakpinimgcomxdfdfadcfeabjpg.jpg, Assigned ID: Person_44012e07
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/ben_afflek/httpwwwrumenewscomwpcontentuploadsbenafflekxpng.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpwwwimpropercomimagesuploadsusercontentimagesSoroffMindyjpg.jpg, Assigned ID: Person_4dab0d9b
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpssmediacacheakpinimgcomxbabafeacbaaacabffjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpcdncdnjustjaredcomwpcontentuploadsheadlinesmindykalingcomedypilotjpg.jpg, Assigned ID: Person_4dab0d9b
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpssmediacacheakpinimgcomxeedccadejpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpmediaonsugarcomfilesbabaaaaaMindyInterviewxxxlargejpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpcdnpastemagazinecomwwwarticlesmindykalingndbookjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpssmediacacheakpinimgcomxededbebccdajpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httppixelnymagcomimgsfashiondailymindykalingwhjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpcdnpastemagazinecomwwwarticlesmindyprojectjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpssmediacacheakpinimgcomxcccccddbbfedabjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpimagesnymagcomimagesdailymindykalingxjpg.jpg, Assigned ID: Person_49eab735
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpsimgbuzzfeedcombuzzfeedstaticstaticcampaignimageswebdradorableetsyitemsallmindykalingfansneedbigjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpwwwadweekcomfilesimagecachenodeinlinemindykalingprofilehedjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpafilesbiographycomimageuploadcfillcssrgbdprgfacehqwMTIOTcwODQNTUzNjQMzcjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpgonetworthcomwpcontentuploadsthumbsjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpgraphicsnytimescomimagesmagazinekalingkalingarticleInlinejpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpdbrbzkkbdsdcloudfrontnetwpcontentuploadsMindyKalingjpg.jpg, Assigned ID: Person_4bbd99e7
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpwwwpictureszimbiocomgiMindyKalingLkvEhTwDeJmjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpwwwbooksforbetterlivingcomwpcontentuploadsMindyKalingAuthorPhotojpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpwwwpictureszimbiocomfpMindyKalingfBgaONVFDFmjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpsimagesnasslimagesamazoncomimagesIAQdwKvFILUXjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpwwweonlinecomeolimagesEntireSiteregKalingCancermhjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpssmediacacheakpinimgcomxccccdabeaadjpg.jpg, Assigned ID: Person_9f37bc7e
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpssmediacacheakpinimgcomxbbfcbdedfbfdbjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpsamazonawscomkidzworldphotoimagesbccdddaaadgallerymindykalinggalleryjpg.jpg, Assigned ID: Person_4dab0d9b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpsuploadwikimediaorgwikipediacommonsthumbMindyBKalingBPaleyFestBNewBYorkBBMindyBIqZgUWvbljpgpxMindyBKalingBPaleyFestBNewBYorkBBMindyBIqZgUWvbljpg.jpg, Assigned ID: Person_4dab0d9b
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/mindy_kaling/httpssmediacacheakpinimgcomxafaffbbbbdbcbdddjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpmediapopsugarassetscomfilescbffewltonjpg.jpg, Assigned ID: Person_f4cd56d5
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpwwwlautdeEltonJohneltonjohnjpg.jpg, Assigned ID: Person_6408f45b
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpcdnlyricssongonlyricsnetwpcontentuploadsEltonJohnDiscographyCDreleasesjpg.jpg, Assigned ID: Person_1adf5887
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpssmediacacheakpinimgcomxfefdacfbfdeadajpg.jpg, Assigned ID: Person_5997bbb7
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpssmediacacheakpinimgcomxfcfcbaeaeddabbjpg.jpg, Assigned ID: Person_52a3cc5f
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpssmediacacheakpinimgcomxfcfcbaeaeddabbjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpsuploadwikimediaorgwikipediacommonsthumbEltonJohninsjpgpxEltonJohninsjpg.jpg, Assigned ID: Person_ddf91595
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpssmediacacheakpinimgcomxfecfecaefaadfebejpg.jpg due to blurr
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpftqncomymusicLxZeltonjohnjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpmediacacheecpinimgcomxffeffbcefjpg.jpg, Assigned ID: Person_52a3cc5f
# skipped /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpcdncdnjustjaredcomwpcontentuploadsheadlineseltonjohnemmysperformancewatchnowjpg.jpg due to blurr
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpafilesbiographycomimageuploadcfillcssrgbdprgfacehqwMTEODAOTcxNjcMjczMjkzjpg.jpg, Assigned ID: Person_f4cd56d5
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpcdncdnjustjaredcomwpcontentuploadsheadlineseltonjohnstillstandingbrooklynnewyearsjpg.jpg, Assigned ID: Person_f4cd56d5
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpiamediaimdbcomimagesMMVBMTAxNDUMzUwOTdeQTJeQWpwZBbWUMDUOTAyNTIVUXCRALjpg.jpg, Assigned ID: Person_f4cd56d5
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpcdncdnjustjaredcomwpcontentuploadsheadlineseltonjohnsupportsbrucejennerstransitiontowomanjpg.jpg, Assigned ID: Person_f4cd56d5
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpimagesmtvcomurimgidfiledocrootvhcomsitewideflipbooksimgdailyjpgenlargefalsemattetruematteColorblackquality.jpg, Assigned ID: Person_f4cd56d5
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpsdfrpwlycscloudfrontnetdeltonjohnjpg.jpg, Assigned ID: Person_6fc8167e
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpwwwjohnpauljonesarenacomeventimagesEltonCalendarVjpg.jpg, Assigned ID: Person_f971ad57
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpwwwdeadlinecomvimgnetwpcontentuploadseltonjpg.jpg, Assigned ID: Person_f4cd56d5
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpspmctvlinefileswordpresscomeltonjohnjpg.jpg, Assigned ID: Person_f4cd56d5
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpwwweonlinecomresizewwweonlinecomeolimagesEntireSitersxEltonJohnJRjpg.jpg, Assigned ID: Person_f971ad57
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpsticketmnettmenusdamabbacdaebeafdbbCUSTOMjpg.jpg, Assigned ID: Person_f4cd56d5
# Image: /mnt/113117fa-e8af-4d8b-9b69-072b1b91c742/Code/facialRegonitionModel/f_celeb/elton_john/httpimggalpmdstaticnetfithttpAFFwwwEgalaEfrFvarFgalFstorageFimagesFmediaFmultiuploaddufevrierFeltonjohnFfreFRFeltonjohnEjpgxqualityeltonjohnjpg.jpg, Assigned ID: Person_f4cd56d5
